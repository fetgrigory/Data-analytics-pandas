# %%
'''
This module make

Athor: Fetkulin Grigory, Fetkulin.G.R@yandex.ru
Starting 06/01/2025
Ending 2025//

'''
# Installing the necessary libraries
import pandas as pd

# %%
# Load data from 'data_1.csv' with UTF-8 encoding
df = pd.read_csv('data\data_1.csv', encoding='utf-8')
df
# Out:
#                          Product  Quantity    Price                 Date  \
# 0             Macbook Pro Laptop         1  1700.00  2019-12-30 00:01:00
# 1             LG Washing Machine         1   600.00  2019-12-29 07:03:00
# 2           USB-C Charging Cable         1    11.95  2019-12-12 18:21:00
# 3               27in FHD Monitor         1   149.99  2019-12-22 15:13:00
# 4           USB-C Charging Cable         1    11.95  2019-12-18 12:38:00
# ...                          ...       ...      ...                  ...
# 4995            27in FHD Monitor         1   149.99  2019-12-25 16:54:00
# 4996        USB-C Charging Cable         3    11.95  2019-12-11 12:08:00
# 4997  Bose SoundSport Headphones         1    99.99  2019-12-19 12:10:00
# 4998          Macbook Pro Laptop         1  1700.00  2019-12-08 18:26:00
# 4999        USB-C Charging Cable         1    11.95  2019-12-03 12:25:00
#
#                                      Address    Total
# ...

# %%
df[ df.Quantity > 2 ] # Filter rows where the Quantity column is greater than 2
# Out:
#                      Product  Quantity  Price                 Date  \
# 9     AAA Batteries (4-pack)         4   2.99  2019-12-28 11:51:00
# 22    AAA Batteries (4-pack)         4   2.99  2019-12-04 12:29:00
# 46    AAA Batteries (4-pack)         3   2.99  2019-12-12 20:08:00
# 65    AAA Batteries (4-pack)         3   2.99  2019-12-05 15:01:00
# 91     AA Batteries (4-pack)         3   3.84  2019-12-10 21:50:00
# ...                      ...       ...    ...                  ...
# 4812   AA Batteries (4-pack)         4   3.84  2019-12-08 07:17:00
# 4872  AAA Batteries (4-pack)         3   2.99  2019-12-22 05:44:00
# 4957  AAA Batteries (4-pack)         3   2.99  2019-12-21 18:04:00
# 4961   AA Batteries (4-pack)         3   3.84  2019-12-08 15:10:00
# 4996    USB-C Charging Cable         3  11.95  2019-12-11 12:08:00
#
#                                      Address  Total
# 9                77 7th St, Dallas, TX 75001  11.96
# 22    936 Church St, San Francisco, CA 94016  11.96
# ...

# %%
df[ (df.Product.str.contains('Batteries')) & (df.Total > 10) ]  # Filter rows where the Product contains 'Batteries' and Total is greater than 10
# Out:
#                      Product  Quantity  Price                 Date  \
# 9     AAA Batteries (4-pack)         4   2.99  2019-12-28 11:51:00
# 22    AAA Batteries (4-pack)         4   2.99  2019-12-04 12:29:00
# 91     AA Batteries (4-pack)         3   3.84  2019-12-10 21:50:00
# 163    AA Batteries (4-pack)         3   3.84  2019-12-24 08:29:00
# 338    AA Batteries (4-pack)         3   3.84  2019-12-06 10:46:00
# ...                      ...       ...    ...                  ...
# 4536  AAA Batteries (4-pack)         6   2.99  2019-12-10 19:29:00
# 4669   AA Batteries (4-pack)         3   3.84  2019-12-20 14:43:00
# 4739  AAA Batteries (4-pack)         4   2.99  2019-12-14 21:07:00
# 4812   AA Batteries (4-pack)         4   3.84  2019-12-08 07:17:00
# 4961   AA Batteries (4-pack)         3   3.84  2019-12-08 15:10:00
#
#                                      Address  Total
# 9                77 7th St, Dallas, TX 75001  11.96
# 22    936 Church St, San Francisco, CA 94016  11.96
# ...
