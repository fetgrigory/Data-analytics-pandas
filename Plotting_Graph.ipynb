# %%
'''
This module make

Athor: Fetkulin Grigory, Fetkulin.G.R@yandex.ru
Starting 20/01/2025
Ending //2025

'''
# Installing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data from 'data_4.csv' with UTF-8 encoding
df = pd.read_csv('data\data_4.csv', encoding='utf-8')
df
# Out:
#                          Product  Quantity    Price                 Date  \
# 0       Lightning Charging Cable         1    14.95  2019-12-03 10:54:00
# 1          AA Batteries (4-pack)         2     3.84  2019-12-01 16:55:00
# 2          AA Batteries (4-pack)         1     3.84  2019-12-04 11:30:00
# 3       Lightning Charging Cable         1    14.95  2019-12-25 13:41:00
# 4           USB-C Charging Cable         1    11.95  2019-12-05 12:27:00
# ...                          ...       ...      ...                  ...
# 4995  Bose SoundSport Headphones         1    99.99  2019-12-30 12:46:00
# 4996  Bose SoundSport Headphones         1    99.99  2019-12-14 08:28:00
# 4997    Lightning Charging Cable         1    14.95  2019-12-17 20:00:00
# 4998  Bose SoundSport Headphones         1    99.99  2019-12-28 11:06:00
# 4999          Macbook Pro Laptop         1  1700.00  2019-12-25 15:46:00
#
#                                       Address    Total
# ...

# %%
# Counting the number of items sold by type
product_counts = df['Product'].value_counts()
print(product_counts)
# Out:
# Product
# USB-C Charging Cable          630
# AAA Batteries (4-pack)        563
# Lightning Charging Cable      554
# AA Batteries (4-pack)         543
# Wired Headphones              488
# Apple Airpods Headphones      411
# Bose SoundSport Headphones    381
# 27in 4K Gaming Monitor        197
# 27in FHD Monitor              193
# 34in Ultrawide Monitor        167
# iPhone                        166
# Google Phone                  145
# Flatscreen TV                 135
# Macbook Pro Laptop            133
# ThinkPad Laptop               111
# 20in Monitor                  107
# Vareebadd Phone                48
# LG Washing Machine             14
# LG Dryer                       14
# Name: count, dtype: int64

# %%
 # Unique product names
product_names = product_counts.index
 # Number of units sold for each product
quantities = product_counts.values

# %%
# Set the chart size
plt.figure(figsize=(10, 6))

# Create a bar chart with product names and their quantities
# Specify the bar color (skyblue) and edge color (black)
plt.bar(product_names, quantities, color='skyblue', edgecolor='black')

# Add a label for the X-axis (products)
plt.xlabel('Product', fontsize=12)

# Add a label for the Y-axis (quantity sold)
plt.ylabel('Quantity Sold', fontsize=12)

# Add a title for the chart
plt.title('Quantity of Products Sold by Type', fontsize=14)

# Rotate the X-axis captions and (horizontal alignment) aligns the text to the right.
plt.xticks(rotation=45, ha='right')

# This command automatically adjusts the sizes of all elements (for example, captions and headings) so that they do not overlap and do not go beyond the boundaries of the graph.
plt.tight_layout()

# Display the bar chart
plt.show()
